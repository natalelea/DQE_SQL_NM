# %%
import pandas as pd

# %%
pd.options.display.max_rows = 10

source_file = pd.read_csv('customers-10000.csv')

print(source_file.head(2))
# Out:
#    Index  Organization Id            Name                    Website  \
# 0      1  522816eF8fdBE6d    Mckinney PLC           http://soto.com/
# 1      2  70C7FBD7e6Aa3Ea  Cunningham LLC  http://harding-duffy.com/
#
#      Country                           Description  Founded Industry  \
# 0  Sri Lanka       Synergized global system engine     1988    Dairy
# 1    Namibia  Team-oriented fault-tolerant adapter     2018  Library
#
#    Number of employees
# 0                 3930
# 1                 7871

# %%
usecols = ["Organization Id", "Name", "Country", "Founded", "Industry", "Number of employees"]

df = pd.read_csv('customers-10000.csv', index_col="Organization Id", usecols=usecols)

print(df.head(5))
# Out:
#                                         Name  \
# Organization Id
# 522816eF8fdBE6d                 Mckinney PLC
# 70C7FBD7e6Aa3Ea               Cunningham LLC
# 428B397eA2d7290                   Ruiz-Walls
# 9D234Ae8Cc51C1c  Parrish, Osborne and Clarke
# 6CDCcdE3D0b7b44       Diaz, Robles and Haley
#
#                                                            Country  Founded  \
# Organization Id
# 522816eF8fdBE6d                                          Sri Lanka     1988
# 70C7FBD7e6Aa3Ea                                            Namibia     2018
# 428B397eA2d7290                                               Iran     2003
# 9D234Ae8Cc51C1c  British Indian Ocean Territory (Chagos Archipe...     1989
# 6CDCcdE3D0b7b44                                           Botswana     2013
#
#                                Industry  Number of employees
# Organization Id
# 522816eF8fdBE6d                   Dairy                 3930
# 70C7FBD7e6Aa3Ea                 Library                 7871
# 428B397eA2d7290  Hospital / Health Care                 3095
# 9D234Ae8Cc51C1c            Supermarkets                 5422
# 6CDCcdE3D0b7b44          Nanotechnology                 3135

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 522816eF8fdBE6d to 0D3b7DcFA21d92d
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 10000 non-null  object
#  1   Country              10000 non-null  object
#  2   Founded              10000 non-null  int64
#  3   Industry             10000 non-null  object
#  4   Number of employees  10000 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 468.8+ KB

# %%
duplicates_counter = 0

for i in df.duplicated():
    if i == True:
        duplicates_counter += 1
        
print(duplicates_counter)
# Out:
# 0

# %%
df.aggregate({"Founded":['min', 'max']})
# Out:
#      Founded
# min     1970
# max     2022

# %%
prev_cent_count = 0

for i in df["Founded"]:
    if i <= 2000:
        prev_cent_count += 1
        
print(prev_cent_count)
# Out:
# 5911

# %%
for x in df.index:
    if df.loc[x, "Founded"] <= 2000:
        df.loc[x, "Founded"] = '20th century'
    else:
        df.loc[x, "Founded"] = '21th century'

# %%
prev_cent_count = 0

for i in df["Founded"]:
    if i == '20th century':
        prev_cent_count += 1
        
print(prev_cent_count)
# Out:
# 5911

# %%
df.aggregate({"Founded":['min', 'max']})
# Out:
#           Founded
# min  20th century
# max  21th century

# %%
desc = df["Number of employees"].describe()

print(desc["count"], desc["min"], desc["max"])
# Out:
# 10000.0 1.0 9999.0

# %%
for x in df.index:
    if df.loc[x, "Number of employees"] < 1000:
        df.drop(x, inplace = True)

# %%
df["Number of employees"].describe()
# Out:
# count    8946.000000
# mean     5485.608428
# std      2619.216746
# min      1001.000000
# 25%      3208.000000
# 50%      5456.500000
# 75%      7789.750000
# max      9999.000000
# Name: Number of employees, dtype: float64

# %%
df.groupby(['Industry']).groups
# Out:
C2943e7A1', 'Fc1d59ba96Eda4C', 'dE3eeD2Be84607b', '19a07cbca2FD6D9', 'b6a3B56Adb2cc9B', 'Cb9b146FE9C68dD', '1CDf37647cc539e', '22d6A2d4f22eAB0', 'ECC4e77fCFEEC5A', '8cB1e355cfC1a5d', '9EddBDCffD3bbf2'], 'Alternative Dispute Resolution': ['dFe6bCAe214A0DD', '4d99EF63d9eA80d', '057a6d4f9bee3DB', '9cEE6daB3dCEa6e', '6DcFf8983B2Fc38', 'b5dddfc3e34eeF0', 'ae7acfbB8E4Fe5F', 'C5Aa05DbECC94a3', 'B81AE2cbB320468', 'fFF6AAD71E9c45f', 'DdE0dCD5Fb4fC51', 'Fd5AFcf0Ab0e6DD', '6b718Ae3098CD15', 'CD7Ca56D7fDaDc5', 'Bc5BaCf45c732b9', '81CDb4E8E85752E', 'E618d2c48D5FEb5', 'B5C8aad1c747DCD', 'D3e4aD78AeBE6B4', 'E5Cc9c3969cdCBF', 'E64de4D36877aF7', 'Fa5cD9eA70cBB4f', 'b590B6E734Be0b9', '64EDE144792cd49', 'edcBcA6abFc7ADE', 'CB2CeC36acCAC44', '145f93D2dDAaFe9', 'E5D7Bfb147ACb17', 'AAAAfA672a5E0FF', '1903EfD3CcFe0f8', '51d2aebfC464DE2', 'f0CC5CAf4d503B7', '7CC024920ADeE8a', '8DCdA2842Ad0Dfb', '091673dCEaA4BBF', '7aCECD9d54d0415', 'bd91CB36A1B98B9', 'E6afc545723E3dE', 'c9a0BDefABcbeff', 'B281ADC25C917ec', 'cbDEC1443aa2bdB', 'aE65Eb120d1D37B', 'Dd6ac6a7FFFBcB2', 'd8bFEDd46414dD8', 'f179E450B45Cf54', 'df85dCD2117A046', 'ceCCEdC4e461748', '2DdB2EDCbcBd8AA', 'B54B4f1763c00f9', '0FBE7EA1Af1D495', '995187de3D611Dd', 'CEB10aD67131D09', 'a1fFeBEB13aFBEC', 'Fd7A7FC6A36f050', 'FA50dFe13bd6BCA', 'daDa61C2AfAcEBC', '5F9cE48BFeFe30C', 'EA3eC54Bd5e8ea1', 'CfF07A85Ea020d2', '7f57bf99ec5F3Ed', 'Af50Ae03Ebee8D9', 'C6fDBF18EEb50fC', 'F80C5FB60dC78B2', 'a31DB0B26BC110a', 'BFaB8cE713f2804', '93A9Ba43cad615e', '779aDD29ADf8009'], 'Alternative Medicine': ['64dD5a69f0E27c0', '7EFf64aFeed4fB6', 'Fd42A775dcc45dd', '0a6eFcd93dbb4dF', 'd636fea7c8C0Efb', 'Ff5AfaE3AA9AbA2', 'D952FdCCA3e44fA', 'Ccf08bD4AcdaB56', '404EF5b8fC9cBb3', '94baC0152703CeB', '22ea94D7055deE2', '8bDf22Dba6CD080', 'D ...

# %%
df["Industry"] = df["Industry"].str.upper() 

print(df)
# Out:
#                                         Name  \
# Organization Id
# 522816eF8fdBE6d                 Mckinney PLC
# 70C7FBD7e6Aa3Ea               Cunningham LLC
# 428B397eA2d7290                   Ruiz-Walls
# 9D234Ae8Cc51C1c  Parrish, Osborne and Clarke
# 6CDCcdE3D0b7b44       Diaz, Robles and Haley
# ...                                      ...
# 2EE82AD1Cd045cd           Neal, Day and Wang
# 06f1568A2CaF04a    Barrett, Rojas and Adkins
# B4B92A44e0331Bc               Franklin-Ayala
# 01D2539e270CEbd                  Wolfe-Mckee
# 0D3b7DcFA21d92d                     Beck LLC
#
#                                                            Country  \
# Organization Id
# 522816eF8fdBE6d                                          Sri Lanka
# 70C7FBD7e6Aa3Ea                                            Namibia
# 428B397eA2d7290                                               Iran
# 9D234Ae8Cc51C1c  British Indian Ocean Territory (Chagos Archipe...
# 6CDCcdE3D0b7b44                                           Botswana
# ...                                                            ...
# 2EE82AD1Cd045cd                                         San Marino
# 06f1568A2CaF04a                                       Turkmenistan
# B4B92A44e0331Bc                                              Yemen
# 01D2539e270CEbd                                               Togo
# 0D3b7DcFA21d92d                                            Georgia
#
#                       Founded                Industry  Number of employees
# Organization Id
# 522816eF8fdBE6d  20th century                   DAIRY                 3930
# 70C7FBD7e6Aa3Ea  21th century                 LIBRARY                 7871
# 428B397eA2d7290  21th century  HOSPITAL / HEALTH CARE                 3095
# 9D234Ae8Cc51C1c  20th century            SUPERMARKETS                 5422
# 6CDCcdE3D0b7b44  21th century          NANOTECHNOLOGY                 3135
# ...                       ...                     ...                  ...
# 2EE82AD1Cd045cd  21th century         IMPORT / EXPORT                 6123
# 06f1568A2CaF04a  21th century    HUMAN RESOURCES / HR                 9043
# B4B92A44e0331Bc  20th century      FINANCIAL SERVICES                 8951
# 01D2539e270CEbd  20th century  ENVIRONMENTAL SERVICES                 2505
# 0D3b7DcFA21d92d  21th century                WIRELESS                 4552
#
# [8946 rows x 5 columns]

# %%
df["Industry"] = df["Industry"].replace("MEDIA PRODUCTION", "MEDIA")

# %%
filter = df["Industry"] == "MEDIA PRODUCTION"
 
df.where(filter).dropna()
# Out:
# Empty DataFrame
# Columns: [Name, Country, Founded, Industry, Number of employees]
# Index: []

# %%
filter = df["Industry"] == "MEDIA"
 
df.where(filter).dropna()
# Out:
#                                            Name                   Country  \
# Organization Id
# cC57130E3F0da7c    Moreno, Caldwell and Estrada                    Turkey
# 23Ab495Bb251AbC                      Booker Inc            Czech Republic
# b7eD0cfA9ce7aab                      Ingram LLC            Western Sahara
# 175fFB5Bd89DCBF                     Salazar-Lee             French Guiana
# aFcafB5B53Ad991                   Ellison-Russo  Northern Mariana Islands
# ...                                         ...                       ...
# fAC43Fc2e2e1aA9      Barron, Benitez and Flores             Liechtenstein
# cBcbc4cfb31872F                 Manning-Barrett              South Africa
# FDBbfF4aA6D8B02  Christian, Mendoza and Mullins                     Nepal
# Be71de763Ec5ae5       Hobbs, Herrera and Molina                     Chile
# cFCC78f9fA4B4e3                       Jones Ltd                 Mauritius
#
#                       Founded Industry  Number of employees
# Organization Id
# cC57130E3F0da7c  21th century    MEDIA               9785.0
# 23Ab495Bb251AbC  21th century    MEDIA               9789.0
# b7eD0cfA9ce7aab  21th century    MEDIA               2697.0
# 175fFB5Bd89DCBF  20th century    MEDIA               9953.0
# aFcafB5B53Ad991  20th century    MEDIA               2970.0
# ...                       ...      ...                  ...
# fAC43Fc2e2e1aA9  21th century    MEDIA               3873.0
# cBcbc4cfb31872F  21th century    MEDIA               8946.0
# FDBbfF4aA6D8B02  20th century    MEDIA               7402.0
# Be71de763Ec5ae5  20th century    MEDIA               9843.0
# cFCC78f9fA4B4e3  20th century    MEDIA               5379.0
#
# [60 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# pip install matplotlib

# %%
plt.style.use('dark_background') 

df["Founded"].hist()
# Out:
# <Axes: >

# %%
df["Number of employees"].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.to_csv("processed_data.csv")
